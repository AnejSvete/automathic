# %%
from automathic.fo.parser import parse_fo_formula

# from automathic.fo.translator import SOMtoFSA

# %%
# φ_0 = "exists x. (forall z. (z >= x) and Qa(x))"
# φ_0 = "forall x. (forall z. (z >= x) => Qa(x))"


# φ = parse_fo_formula(φ_0).to_basic_form()
# φ = parse_fo_formula(φ_0)
# print(φ)
# A = φ.to_fsa(alphabet=["a", "b"]).reindex()

# %%
# φ

# %%
# A = φ.to_fsa(alphabet=["a", "b"]).reindex()

# %%
# A

# %%
# φ_ = A.to_som().to_basic_form()

# %%
# A_ = φ_.to_fsa(alphabet=["a"]).reindex()

# %%
# A_

# %%
from automathic.fsa.example_fsas import (
    create_starts_with_a_and_ends_with_b_automaton,
    create_substring_abc_automaton,
    create_end_with_ab_automaton,
    create_divisible_by_3_automaton,
    create_contains_a_followed_by_b_automaton,
    create_even_parity_automaton,
    create_odd_parity_automaton,
    create_even_length_automaton,
    create_even_number_of_as_automaton,
    create_sigma_star_automaton,
    create_alternating_ab_automaton,
)

# %%
# A = create_sigma_star_automaton()
# A = create_substring_abc_automaton()
# A = create_even_length_automaton()
# A = create_odd_parity_automaton()
# A = create_even_parity_automaton()
# A = create_alternating_ab_automaton()
# A = create_contains_a_followed_by_b_automaton()
A = create_starts_with_a_and_ends_with_b_automaton()

# %%
A
# Out:
#         <script>
#         try {
#             require.config({
#                 paths: {
#                     "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3",
#                     "dagreD3": "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min"
#                 }
#             });
#         } catch (e) {
#             ["https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3.js",
#             "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min.js"].forEach(
#                 function (src) {
#                     var tag = document.createElement('script');
#                     tag.src = src;
#                     document.body.appendChild(tag);
#                 }
#             );
#         }
#         try {
#             requirejs(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         try {
#             require(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         </script>
#
#         <style>
#         /* Import LaTeX-like font */
#         @import url('https://fonts.googleapis.com/css2?family=Source+Serif+Pro:wght@400;600&display=swap');
#
#         .node rect,
#         .node circle,
#         .node ellipse {
#             stroke: rgb(192, 192, 192);
#             /* Don't set stroke-width here, it's applied per-node */
#         }
#
#         .edgePath path {
#             stroke: rgb(192, 192, 192);
#             fill: rgb(192, 192, 192);
#             stroke-width: 1.5px;
#         }
#
#         /* LaTeX-like typography */
#         .node text {
#             font-family: 'Source Serif Pro', 'Computer Modern', 'Latin Modern Math', serif;
#             font-size: 14px;
#             font-weight: normal;
#             fill: #ffffff !important; /* Force text color */
#         }
#
#         .edgeLabel text {
#             font-family: 'Source Serif Pro', 'Computer Modern', 'Latin Modern Math', serif;
#             font-size: 12px;
#             font-weight: normal;
#             fill: rgb(192, 192, 192) !important; /* Force edge label color */
#         }
#         </style>
#         <center><svg width="850" height="600" id="fsa_0d4c0de5_8ef8_4bd3_9d87_e8d6d736d761"><g/></svg></center>
#         <script>
#         (function render_d3() {
#             var d3, dagreD3;
#             try {
#                 d3 = require('d3');
#                 dagreD3 = require('dagreD3');
#             } catch (e) {
#                 if(typeof window.d3 !== "undefined" && typeof window.dagreD3 !== "undefined"){
#                     d3 = window.d3;
#                     dagreD3 = window.dagreD3;
#                 } else {
#                     setTimeout(render_d3, 50);
#                     return;
#                 }
#             }
#
#             // Create directed graph
#             var g = new dagreD3.graphlib.Graph().setGraph({
#                 rankdir: 'LR',
#                 marginx: 20,
#                 marginy: 20,
#                 ranksep: 50,
#                 nodesep: 30
#             });
#         g.setNode("0", { label: "0", shape: "circle", style: "fill: #88c0d0; stroke: rgb(192, 192, 192); stroke-width: 1px;" });
# g.setNode("1", { label: "1", shape: "circle", style: "fill: #4c566a; stroke: rgb(192, 192, 192); stroke-width: 1px;" });
# g.setNode("2", { label: "2", shape: "circle", style: "fill: #bf616a; stroke: rgb(192, 192, 192); stroke-width: 3px;" });
# g.setEdge("0", "1", { label: "a", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("0", "0", { label: "b, c", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("1", "1", { label: "a, c", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("1", "2", { label: "b", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("2", "1", { label: "a, c", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("2", "2", { label: "b", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setNode("start", { label: "", width: 0, height: 0, style: "opacity: 0" });
# g.setEdge("start", "0", { label: "", arrowhead: "normal", style: "stroke: rgb(192, 192, 192); fill: none;", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# var svg = d3.select("#fsa_0d4c0de5_8ef8_4bd3_9d87_e8d6d736d761");
#
#             var inner = svg.select("g");
#
#             // Set up zoom support
#             var zoom = d3.zoom().scaleExtent([0.3, 5]).on("zoom", function() {
#                 inner.attr("transform", d3.event.transform);
#             });
#             svg.call(zoom);
#
#             // Create the renderer
#             var render = new dagreD3.render();
#
#             // Render the graph
#             render(inner, g);
#
#             // Hide start node and apply styles after rendering
#             if (g.hasNode("start")) {
#                 d3.select(g.node("start").elem).style("opacity", "0");
#             }
#
#             // Force labels to be visible with correct colors
#             inner.selectAll("g.node text").style("fill", "#ffffff");
#             inner.selectAll(".edgeLabel text").style("fill", "rgb(192, 192, 192)");
#
#             // Center the graph
#             var initialScale = 0.75;
#             svg.call(zoom.transform, d3.zoomIdentity
#                 .translate((svg.attr("width") - g.graph().width * initialScale) / 2, 20)
#                 .scale(initialScale));
#
#             // Adjust SVG height to fit graph
#             svg.attr('height', g.graph().height * initialScale + 40);
#         })();
#         </script>

# %%
φ = A.to_som()

# %%
print(φ)
# Out:
# ∃X2.(∃X1.(∃X0.((∃x0.(x0 = x0) ∧ (((∀x1.(((x1 ∈ X0 ∨ x1 ∈ X1) ∨ x1 ∈ X2)) ∧ ∀x2.(((¬((x2 ∈ X0 ∧ x2 ∈ X1)) ∧ ¬((x2 ∈ X0 ∧ x2 ∈ X2))) ∧ ¬((x2 ∈ X1 ∧ x2 ∈ X2))))) ∧ (∀x3.((∀x4.(x4 >= x3) → x3 ∈ X0)) ∧ ∀x5.(∀x6.((x6 = x5+1 → ((((((((((x5 ∈ X0 ∧ x6 ∈ X0) → (Qb(x5) ∨ Qc(x5))) ∧ ((x5 ∈ X0 ∧ x6 ∈ X1) → Qa(x5))) ∧ ((x5 ∈ X0 ∧ x6 ∈ X2) → (¬(x5 ∈ X2) ∧ x5 ∈ X2))) ∧ ((x5 ∈ X1 ∧ x6 ∈ X0) → (¬(x5 ∈ X0) ∧ x5 ∈ X0))) ∧ ((x5 ∈ X1 ∧ x6 ∈ X1) → (Qa(x5) ∨ Qc(x5)))) ∧ ((x5 ∈ X1 ∧ x6 ∈ X2) → Qb(x5))) ∧ ((x5 ∈ X2 ∧ x6 ∈ X0) → (¬(x5 ∈ X0) ∧ x5 ∈ X0))) ∧ ((x5 ∈ X2 ∧ x6 ∈ X1) → (Qa(x5) ∨ Qc(x5)))) ∧ ((x5 ∈ X2 ∧ x6 ∈ X2) → Qb(x5)))))))) ∧ ∀x7.((∀x8.(x8 <= x7) → (((x7 ∈ X0 → (¬(x7 ∈ X0) ∧ x7 ∈ X0)) ∧ (x7 ∈ X1 → Qb(x7))) ∧ (x7 ∈ X2 → Qb(x7))))))))))

# %%
φ.to_basic_form().simplify()
# Out:
# ExistentialSetQuantifier(set_variable='X2', subformula=ExistentialSetQuantifier(set_variable='X1', subformula=ExistentialSetQuantifier(set_variable='X0', subformula=Conjunction(left=ExistentialQuantifier(variable='x0', subformula=Negation(subformula=Relation(left='x0', operator='<', right='x0'))), right=Conjunction(left=Conjunction(left=Conjunction(left=Negation(subformula=ExistentialQuantifier(variable='x1', subformula=Conjunction(left=Conjunction(left=Negation(subformula=X0(x1)), right=Negation(subformula=X1(x1))), right=Negation(subformula=X2(x1))))), right=Negation(subformula=ExistentialQuantifier(variable='x2', subformula=Negation(subformula=Conjunction(left=Conjunction(left=Negation(subformula=Conjunction(left=X0(x2), right=X1(x2))), right=Negation(subformula=Conjunction(left=X0(x2), right=X2(x2)))), right=Negation(subformula=Conjunction(left=X1(x2), right=X2(x2)))))))), right=Conjunction(left=Negation(subformula=ExistentialQuantifier(variable='x3', subformula=Conjunction(left=Negation(subformula=ExistentialQuantifier(variable='x4', subformula=Conjunction(left=Negation(subformula=Relation(left='x3', operator='<', right='x4')), right=Negation(subformula=Conjunction(left=Negation(subformula=Relation(left='x4', operator='<', right='x3')), right=Negation(subformula=Relation(left='x3', operator='<', right='x4'))))))), right=Negation(subformula=X0(x3))))), right=Negation(subformula=ExistentialQuantifier(variable='x5', subformula=ExistentialQuantifier(variable='x6', subformula=Conjunction(left=Conjunction(left=Relation(left='x5', operator='<', right='x6'), right=Negation(subformula=ExistentialQuantifier(variable='z', subformula=Conjunction(left=Relation(left='x5', operator='<', right='z'), right=Relation(left='z', operator='<', right='x6'))))), right=Negation(subformula=Conjunction(left=Conjunction(left=Conjunction(left=Conjunction(left=Conjunction(left=Conjunction(left=Conjunction(left=Conjunction(left=Negation(subformula=Conjunction(left=Conjunction(left=X0(x5), right=X0(x6)), right=Conjunction(left=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='b')), right=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='c'))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X0(x5), right=X1(x6)), right=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='a'))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X0(x5), right=X2(x6)), right=Negation(subformula=Conjunction(left=Negation(subformula=X2(x5)), right=X2(x5)))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X1(x5), right=X0(x6)), right=Negation(subformula=Conjunction(left=Negation(subformula=X0(x5)), right=X0(x5)))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X1(x5), right=X1(x6)), right=Conjunction(left=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='a')), right=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='c')))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X1(x5), right=X2(x6)), right=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='b'))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X2(x5), right=X0(x6)), right=Negation(subformula=Conjunction(left=Negation(subformula=X0(x5)), right=X0(x5)))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X2(x5), right=X1(x6)), right=Conjunction(left=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='a')), right=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='c')))))), right=Negation(subformula=Conjunction(left=Conjunction(left=X2(x5), right=X2(x6)), right=Negation(subformula=SymbolPredicate(name='Q', variable='x5', symbol='b')))))))))))), right=Negation(subformula=ExistentialQuantifier(variable='x7', subformula=Conjunction(left=Negation(subformula=ExistentialQuantifier(variable='x8', subformula=Conjunction(left=Negation(subformula=Relation(left='x8', operator='<', right='x7')), ...

# %%
# A_ = φ.to_basic_form().simplify().to_fsa(alphabet=["0", "1"]).reindex()
# A_ = φ.to_basic_form().simplify().to_fsa(alphabet=["a", "b"]).reindex()

# %%
A_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 A_
#
# NameError: name 'A_' is not defined

# %%
A
# Out:
#         <script>
#         try {
#             require.config({
#                 paths: {
#                     "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3",
#                     "dagreD3": "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min"
#                 }
#             });
#         } catch (e) {
#             ["https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3.js",
#             "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min.js"].forEach(
#                 function (src) {
#                     var tag = document.createElement('script');
#                     tag.src = src;
#                     document.body.appendChild(tag);
#                 }
#             );
#         }
#         try {
#             requirejs(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         try {
#             require(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         </script>
#
#         <style>
#         /* Import LaTeX-like font */
#         @import url('https://fonts.googleapis.com/css2?family=Source+Serif+Pro:wght@400;600&display=swap');
#
#         .node rect,
#         .node circle,
#         .node ellipse {
#             stroke: rgb(192, 192, 192);
#             /* Don't set stroke-width here, it's applied per-node */
#         }
#
#         .edgePath path {
#             stroke: rgb(192, 192, 192);
#             fill: rgb(192, 192, 192);
#             stroke-width: 1.5px;
#         }
#
#         /* LaTeX-like typography */
#         .node text {
#             font-family: 'Source Serif Pro', 'Computer Modern', 'Latin Modern Math', serif;
#             font-size: 14px;
#             font-weight: normal;
#             fill: #ffffff !important; /* Force text color */
#         }
#
#         .edgeLabel text {
#             font-family: 'Source Serif Pro', 'Computer Modern', 'Latin Modern Math', serif;
#             font-size: 12px;
#             font-weight: normal;
#             fill: rgb(192, 192, 192) !important; /* Force edge label color */
#         }
#         </style>
#         <center><svg width="850" height="600" id="fsa_282cdf5b_ee77_45af_9967_24f659d6837c"><g/></svg></center>
#         <script>
#         (function render_d3() {
#             var d3, dagreD3;
#             try {
#                 d3 = require('d3');
#                 dagreD3 = require('dagreD3');
#             } catch (e) {
#                 if(typeof window.d3 !== "undefined" && typeof window.dagreD3 !== "undefined"){
#                     d3 = window.d3;
#                     dagreD3 = window.dagreD3;
#                 } else {
#                     setTimeout(render_d3, 50);
#                     return;
#                 }
#             }
#
#             // Create directed graph
#             var g = new dagreD3.graphlib.Graph().setGraph({
#                 rankdir: 'LR',
#                 marginx: 20,
#                 marginy: 20,
#                 ranksep: 50,
#                 nodesep: 30
#             });
#         g.setNode("0", { label: "0", shape: "circle", style: "fill: #88c0d0; stroke: rgb(192, 192, 192); stroke-width: 1px;" });
# g.setNode("1", { label: "1", shape: "circle", style: "fill: #bf616a; stroke: rgb(192, 192, 192); stroke-width: 3px;" });
# g.setEdge("0", "0", { label: "0", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("0", "1", { label: "1", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("1", "1", { label: "0", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("1", "0", { label: "1", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setNode("start", { label: "", width: 0, height: 0, style: "opacity: 0" });
# g.setEdge("start", "0", { label: "", arrowhead: "normal", style: "stroke: rgb(192, 192, 192); fill: none;", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# var svg = d3.select("#fsa_282cdf5b_ee77_45af_9967_24f659d6837c");
#
#             var inner = svg.select("g");
#
#             // Set up zoom support
#             var zoom = d3.zoom().scaleExtent([0.3, 5]).on("zoom", function() {
#                 inner.attr("transform", d3.event.transform);
#             });
#             svg.call(zoom);
#
#             // Create the renderer
#             var render = new dagreD3.render();
#
#             // Render the graph
#             render(inner, g);
#
#             // Hide start node and apply styles after rendering
#             if (g.hasNode("start")) {
#                 d3.select(g.node("start").elem).style("opacity", "0");
#             }
#
#             // Force labels to be visible with correct colors
#             inner.selectAll("g.node text").style("fill", "#ffffff");
#             inner.selectAll(".edgeLabel text").style("fill", "rgb(192, 192, 192)");
#
#             // Center the graph
#             var initialScale = 0.75;
#             svg.call(zoom.transform, d3.zoomIdentity
#                 .translate((svg.attr("width") - g.graph().width * initialScale) / 2, 20)
#                 .scale(initialScale));
#
#             // Adjust SVG height to fit graph
#             svg.attr('height', g.graph().height * initialScale + 40);
#         })();
#         </script>

# %%
A.is_equivalent(A_)
# Out:
# True

# %%
A.union(A_).complement().intersect(A.union(A_).complement())
# Out:
#         <script>
#         try {
#             require.config({
#                 paths: {
#                     "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3",
#                     "dagreD3": "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min"
#                 }
#             });
#         } catch (e) {
#             ["https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3.js",
#             "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min.js"].forEach(
#                 function (src) {
#                     var tag = document.createElement('script');
#                     tag.src = src;
#                     document.body.appendChild(tag);
#                 }
#             );
#         }
#         try {
#             requirejs(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         try {
#             require(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         </script>
#
#         <style>
#         /* Import LaTeX-like font */
#         @import url('https://fonts.googleapis.com/css2?family=Source+Serif+Pro:wght@400;600&display=swap');
#
#         .node rect,
#         .node circle,
#         .node ellipse {
#             stroke: rgb(192, 192, 192);
#             /* Don't set stroke-width here, it's applied per-node */
#         }
#
#         .edgePath path {
#             stroke: rgb(192, 192, 192);
#             fill: rgb(192, 192, 192);
#             stroke-width: 1.5px;
#         }
#
#         /* LaTeX-like typography */
#         .node text {
#             font-family: 'Source Serif Pro', 'Computer Modern', 'Latin Modern Math', serif;
#             font-size: 14px;
#             font-weight: normal;
#             fill: #ffffff !important; /* Force text color */
#         }
#
#         .edgeLabel text {
#             font-family: 'Source Serif Pro', 'Computer Modern', 'Latin Modern Math', serif;
#             font-size: 12px;
#             font-weight: normal;
#             fill: rgb(192, 192, 192) !important; /* Force edge label color */
#         }
#         </style>
#         <center><svg width="850" height="600" id="fsa_4729dea1_165f_4ba6_a6bf_14df6f034fcb"><g/></svg></center>
#         <script>
#         (function render_d3() {
#             var d3, dagreD3;
#             try {
#                 d3 = require('d3');
#                 dagreD3 = require('dagreD3');
#             } catch (e) {
#                 if(typeof window.d3 !== "undefined" && typeof window.dagreD3 !== "undefined"){
#                     d3 = window.d3;
#                     dagreD3 = window.dagreD3;
#                 } else {
#                     setTimeout(render_d3, 50);
#                     return;
#                 }
#             }
#
#             // Create directed graph
#             var g = new dagreD3.graphlib.Graph().setGraph({
#                 rankdir: 'LR',
#                 marginx: 20,
#                 marginy: 20,
#                 ranksep: 50,
#                 nodesep: 30
#             });
#         g.setNode("0", { label: "0", shape: "circle", style: "fill: #ebcb8b; stroke: rgb(192, 192, 192); stroke-width: 3px;" });
# g.setNode("1", { label: "1", shape: "circle", style: "fill: #4c566a; stroke: rgb(192, 192, 192); stroke-width: 1px;" });
# g.setEdge("0", "0", { label: "0", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("0", "1", { label: "1", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("1", "1", { label: "0", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setEdge("1", "0", { label: "1", arrowhead: "vee", style: "stroke: rgb(192, 192, 192); fill: none;", labelStyle: "fill: rgb(192, 192, 192);", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# g.setNode("start", { label: "", width: 0, height: 0, style: "opacity: 0" });
# g.setEdge("start", "0", { label: "", arrowhead: "normal", style: "stroke: rgb(192, 192, 192); fill: none;", arrowheadStyle: "fill: rgb(192, 192, 192); stroke: rgb(192, 192, 192);" });
# var svg = d3.select("#fsa_4729dea1_165f_4ba6_a6bf_14df6f034fcb");
#
#             var inner = svg.select("g");
#
#             // Set up zoom support
#             var zoom = d3.zoom().scaleExtent([0.3, 5]).on("zoom", function() {
#                 inner.attr("transform", d3.event.transform);
#             });
#             svg.call(zoom);
#
#             // Create the renderer
#             var render = new dagreD3.render();
#
#             // Render the graph
#             render(inner, g);
#
#             // Hide start node and apply styles after rendering
#             if (g.hasNode("start")) {
#                 d3.select(g.node("start").elem).style("opacity", "0");
#             }
#
#             // Force labels to be visible with correct colors
#             inner.selectAll("g.node text").style("fill", "#ffffff");
#             inner.selectAll(".edgeLabel text").style("fill", "rgb(192, 192, 192)");
#
#             // Center the graph
#             var initialScale = 0.75;
#             svg.call(zoom.transform, d3.zoomIdentity
#                 .translate((svg.attr("width") - g.graph().width * initialScale) / 2, 20)
#                 .scale(initialScale));
#
#             // Adjust SVG height to fit graph
#             svg.attr('height', g.graph().height * initialScale + 40);
#         })();
#         </script>
