# %%
from automathic.fo.parser import parse_fo_formula

# %%
# Strings that start with a and and with b
φ_0 = """
exists X. (
  (forall x. (!(X(x)) or Qa(x))) and
  (forall x. (forall y. (!(X(x) and y = x + 1 and y in X)))) and
  (forall x. (forall y. (!(!(X(x)) and y = x + 1 and !(y in X))))) and
  (forall x. (!(x = 0) or (X(x))))
)
"""


φ = parse_fo_formula(φ_0)
# φ = φ.simplify()
# φ = φ.to_fo_less().simplify()
print(φ.to_basic_form())
φ.to_basic_form()
# A = φ.to_fsa(alphabet=["a", "b"]).reindex()
# Out:
# ∃X.((((¬(∃x.(¬(¬((¬(¬(X(x))) ∧ ¬(Qa(x))))))) ∧ ¬(∃x.(¬(¬(∃y.(¬(¬(((X(x) ∧ y = x+1) ∧ y ∈ X))))))))) ∧ ¬(∃x.(¬(¬(∃y.(¬(¬(((¬(X(x)) ∧ y = x+1) ∧ ¬(y ∈ X)))))))))) ∧ ¬(∃x.(¬(¬((¬(¬(x = 0)) ∧ ¬(X(x)))))))))
# ExistentialSetQuantifier(set_variable='X', subformula=Conjunction(left=Conjunction(left=Conjunction(left=Negation(subformula=ExistentialQuantifier(variable='x', subformula=Negation(subformula=Negation(subformula=Conjunction(left=Negation(subformula=Negation(subformula=Predicate(name='X', variable='x'))), right=Negation(subformula=SymbolPredicate(name='Q', variable='x', symbol='a'))))))), right=Negation(subformula=ExistentialQuantifier(variable='x', subformula=Negation(subformula=Negation(subformula=ExistentialQuantifier(variable='y', subformula=Negation(subformula=Negation(subformula=Conjunction(left=Conjunction(left=Predicate(name='X', variable='x'), right=Relation(left='y', operator='=', right='x+1')), right=SetMembership(position_variable='y', set_variable='X')))))))))), right=Negation(subformula=ExistentialQuantifier(variable='x', subformula=Negation(subformula=Negation(subformula=ExistentialQuantifier(variable='y', subformula=Negation(subformula=Negation(subformula=Conjunction(left=Conjunction(left=Negation(subformula=Predicate(name='X', variable='x')), right=Relation(left='y', operator='=', right='x+1')), right=Negation(subformula=SetMembership(position_variable='y', set_variable='X'))))))))))), right=Negation(subformula=ExistentialQuantifier(variable='x', subformula=Negation(subformula=Negation(subformula=Conjunction(left=Negation(subformula=Negation(subformula=Relation(left='x', operator='=', right='0'))), right=Negation(subformula=Predicate(name='X', variable='x')))))))))

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 A
#
# NameError: name 'A' is not defined
