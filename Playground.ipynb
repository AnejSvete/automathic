# %%
from parser import parse_fo_formula

# %%
# φ_ = "exists x (exists y (forall z (x < z or x = z) and Qa(x) and forall z (z < y or z = y) and Qb(y)))"
# φ_ = "exists x (forall z (x <= z) and Qa(x))"
# φ_ = "forall z Qa(z)"
# φ_ = "exists x (Qa(x))"
# φ_ = "exists x (exists y (Qa(x) and Qb(y) and x < y))"
φ_ = "exists x (Qa(x) and forall z (x <= z))"
# φ_ = "x <= z"

φ = parse_fo_formula(φ_)
print(φ)
# Out:
# ∃x.((Qa(x) ∧ ∀z.(x <= z)))

# %%
φ
# Out:
# ExistentialQuantifier(variable='x', subformula=Conjunction(left=SymbolPredicate(name='Q', variable='x', symbol='a'), right=UniversalQuantifier(variable='z', subformula=Relation(left='x', operator='<=', right='z'))))

# %%
φ = φ.to_enf()

# %%
φ
# Out:
# ExistentialQuantifier(variable='x', subformula=Negation(subformula=ExistentialQuantifier(variable='z', subformula=Disjunction(left=Negation(subformula=SymbolPredicate(name='Q', variable='x', symbol='a')), right=Negation(subformula=Relation(left='x', operator='<=', right='z'))))))

# %%
φ.subformula.left
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 φ.subformula.left
#
# AttributeError: 'Negation' object has no attribute 'left'

# %%
φ.subformula.left.to_fsa()
# Out:
# Transition: (0,) --('a', ())--> (0,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: ('0',) --('a', ())--> ('0',)
# Transition: ('0',) --('a', ('x',))--> ('1',)
# Transition: ('1',) --('a', ())--> ('1',)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (1,) --('a', ('x',))--> (1,)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (1,) --('a', ('x',))--> (1,)
# Transition: ('1',) --('a', ())--> ('1',)
# Transition: ('1',) --('a', ('x',))--> ('1',)
# Transition: ('0',) --('a', ())--> ('0',)
# Transition: ('0',) --('a', ('x',))--> ('1',)
# ...

# %%
φ.subformula.right
# Out:
# UniversalQuantifier(variable='z', subformula=Relation(left='x', operator='<=', right='z'))

# %%
ψ = φ.subformula.right.to_enf()

# %%
ψ
# Out:
# Negation(subformula=ExistentialQuantifier(variable='z', subformula=Negation(subformula=Relation(left='x', operator='<=', right='z'))))

# %%
φ.subformula.right.to_fsa(alphabet=["a", "b"])
# Out:
# Transition: (0,) --('a', ())--> (0,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (0,) --('a', ('z',))--> (2,)
# Transition: (0,) --('a', ('x', 'z'))--> (3,)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (1,) --('a', ('z',))--> (3,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (2,) --('a', ())--> (2,)
# Transition: (2,) --('a', ('x',))--> (3,)
# Transition: (2,) --('a', ())--> (2,)
# Transition: (3,) --('a', ())--> (3,)
# Transition: (3,) --('a', ())--> (3,)
# Transition: (0,) --('b', ())--> (0,)
# Transition: (0,) --('b', ('x',))--> (1,)
# Transition: (0,) --('b', ('z',))--> (2,)
# Transition: (0,) --('b', ('x', 'z'))--> (3,)
# Transition: (0,) --('b', ())--> (0,)
# Transition: (1,) --('b', ())--> (1,)
# Transition: (1,) --('b', ('z',))--> (3,)
# Transition: (1,) --('b', ())--> (1,)
# Transition: (2,) --('b', ())--> (2,)
# Transition: (2,) --('b', ('x',))--> (3,)
# Transition: (2,) --('b', ())--> (2,)
# ...

# %%
φ.subformula
# Out:
# Conjunction(left=SymbolPredicate(name='Q', variable='x', symbol='a'), right=UniversalQuantifier(variable='z', subformula=Relation(left='x', operator='<=', right='z')))

# %%
φ.subformula.to_fsa(alphabet=["a", "b"])
# Out:
# Transition: (0,) --('a', ())--> (0,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (0,) --('a', ('z',))--> (2,)
# Transition: (0,) --('a', ('x', 'z'))--> (3,)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (1,) --('a', ('z',))--> (3,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (2,) --('a', ())--> (2,)
# Transition: (2,) --('a', ('x',))--> (3,)
# Transition: (2,) --('a', ())--> (2,)
# Transition: (3,) --('a', ())--> (3,)
# Transition: (3,) --('a', ())--> (3,)
# Transition: (0,) --('b', ())--> (0,)
# Transition: (0,) --('b', ('x',))--> (1,)
# Transition: (0,) --('b', ('z',))--> (2,)
# Transition: (0,) --('b', ('x', 'z'))--> (3,)
# Transition: (0,) --('b', ())--> (0,)
# Transition: (1,) --('b', ())--> (1,)
# Transition: (1,) --('b', ('z',))--> (3,)
# Transition: (1,) --('b', ())--> (1,)
# Transition: (2,) --('b', ())--> (2,)
# Transition: (2,) --('b', ('x',))--> (3,)
# Transition: (2,) --('b', ())--> (2,)
# ...

# %%
F = φ.to_fsa(alphabet=["a", "b"])
# Out:
# Transition: (0,) --('a', ())--> (0,)
# Transition: (0,) --('a', ('x',))--> (1,)
# Transition: (0,) --('a', ('z',))--> (2,)
# Transition: (0,) --('a', ('x', 'z'))--> (3,)
# Transition: (0,) --('a', ())--> (0,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (1,) --('a', ('z',))--> (3,)
# Transition: (1,) --('a', ())--> (1,)
# Transition: (2,) --('a', ())--> (2,)
# Transition: (2,) --('a', ('x',))--> (3,)
# Transition: (2,) --('a', ())--> (2,)
# Transition: (3,) --('a', ())--> (3,)
# Transition: (3,) --('a', ())--> (3,)
# Transition: (0,) --('b', ())--> (0,)
# Transition: (0,) --('b', ('x',))--> (1,)
# Transition: (0,) --('b', ('z',))--> (2,)
# Transition: (0,) --('b', ('x', 'z'))--> (3,)
# Transition: (0,) --('b', ())--> (0,)
# Transition: (1,) --('b', ())--> (1,)
# Transition: (1,) --('b', ('z',))--> (3,)
# Transition: (1,) --('b', ())--> (1,)
# Transition: (2,) --('b', ())--> (2,)
# Transition: (2,) --('b', ('x',))--> (3,)
# Transition: (2,) --('b', ())--> (2,)
# ...

# %%
F
# Out:
#        <script>
#        try {
#        require.config({
#        paths: {
#        "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3",
#        "dagreD3": "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min"
#        }
#        });
#        } catch {
#        ["https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3.js",
#        "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min.js"].forEach(
#             function (src) {
#             var tag = document.createElement('script');
#             tag.src = src;
#             document.body.appendChild(tag);
#             }
#         )
#         }
#         try {
#         requirejs(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         try {
#         require(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         </script>
#         <style>
#         .node rect,
#         .node circle,
#         .node ellipse {
#         stroke: #333;
#         fill: #fff;
# ...

# %%
F.retuple()
# Out:
# Transition: (0,) --a--> (0,)
# Transition: (0,) --b--> (0,)
# Transition: (1,) --a--> (0,)
# Transition: (1,) --b--> (1,)
#        <script>
#        try {
#        require.config({
#        paths: {
#        "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3",
#        "dagreD3": "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min"
#        }
#        });
#        } catch {
#        ["https://cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3.js",
#        "https://cdnjs.cloudflare.com/ajax/libs/dagre-d3/0.6.1/dagre-d3.min.js"].forEach(
#             function (src) {
#             var tag = document.createElement('script');
#             tag.src = src;
#             document.body.appendChild(tag);
#             }
#         )
#         }
#         try {
#         requirejs(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         try {
#         require(['d3', 'dagreD3'], function() {});
#         } catch (e) {}
#         </script>
#         <style>
# ...
